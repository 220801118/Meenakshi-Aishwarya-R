# %%
import pandas as pd
d=pd.read_excel("/content/dataload.xlsx")
print("given data:")
print(d)
# Out:
# given data:
#    subject  meen  aishu  indu  logs  rini
# 0    tamil    98     99    99    20    99
# 1  english    99     98    98     2    98
# 2    maths    90     92    90    10    90
# 3  science    97     95    95     8    95
# 4   social   100    100   100     0   100

# %%
df=pd.DataFrame(d)
print(df)
# Out:
#    subject  meen  aishu  indu  logs  rini
# 0    tamil    98     99    99    20    99
# 1  english    99     98    98     2    98
# 2    maths    90     92    90    10    90
# 3  science    97     95    95     8    95
# 4   social   100    100   100     0   100

# %%
print("column heading",df.columns)
# Out:
# column heading Index(['subject', 'meen', 'aishu', 'indu', 'logs', 'rini'], dtype='object')

# %%
print("shape of data",df.shape)
# Out:
# shape of data (5, 6)

# %%
print("one column values\n",df['aishu'])
# Out:
# one column values
#  0     99
# 1     98
# 2     92
# 3     95
# 4    100
# Name: aishu, dtype: int64

# %%
print("slice\n",df[2:4])
# Out:
# slice
#     subject  meen  aishu  indu  logs  rini
# 2    maths    90     92    90    10    90
# 3  science    97     95    95     8    95

# %%
print(df.loc[2])
# Out:
# subject    maths
# meen          90
# aishu         92
# indu          90
# logs          10
# rini          90
# Name: 2, dtype: object

# %%
print([d['aishu']==92])
# Out:
# [0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: aishu, dtype: bool]

# %%
df=d['aishu']/5
print(df)
# Out:
# 0    19.8
# 1    19.6
# 2    18.4
# 3    19.0
# 4    20.0
# Name: aishu, dtype: float64
