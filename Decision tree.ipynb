# %%
import matplotlib.pyplot as plt
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
df = pandas.read_excel("/content/decision tree.xlsx")
print(df)
d = {'uk': 0, 'usa': 1, 'n': 2}
df['nationality'] = df['nationality'].map(d)
d = {'yes': 1, 'no': 0}
df['go'] = df['go'].map(d)
features = ['age', 'experience', 'rank', 'nationality']
x= df[features]
y=df['go']
dtree = DecisionTreeClassifier()
dtree= dtree.fit(x, y)
tree.plot_tree(dtree, feature_names=features)
plt.show()
# Out:
#     age  experience  rank nationality   go
# 0    36          10     9          uk   no
# 1    42          12     4         usa   no
# 2    23           4     6           n   no
# 3    52           4     4         usa   no
# 4    43          21     8         usa  yes
# 5    44          14     5          uk   no
# 6    66           3     7           n  yes
# 7    35          14     9          uk  yes
# 8    52          13     7           n  yes
# 9    35           5     9           n  yes
# 10   24           3     5         usa   no
# 11   18           3     7          uk  yes
# 12   45           9     9          uk  yes
