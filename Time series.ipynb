# %%
import datetime
res=datetime.datetime.now()
print("Today-now:",res)
# Out:
# Today-now: 2024-05-07 14:21:13.467374

# %%
today=datetime.datetime.today()
print("\ntoday:",today)
# Out:
# today: 2024-05-07 14:21:16.759610

# %%
tomorrow=today+datetime.timedelta(days=2)
print("\ntomorrow:",tomorrow)
# Out:
# tomorrow: 2024-05-09 14:21:16.759610

# %%
yesterday=today-datetime.timedelta(days=2)
print("\nyesterday:",yesterday)
# Out:
# yesterday: 2024-05-05 14:21:16.759610

# %%
res=datetime.datetime.now()
res1=datetime.datetime(2024,4,18,2,47,7,331318)
print(res1)
# Out:
# 2024-04-18 02:47:07.331318

# %%
from datetime import date
d=date(2003,10,13)
print("\nreplacing date:",d,d.replace(month=1))
# Out:
# replacing date: 2003-10-13 2003-01-13

# %%
t=date(2003,10,14)
d=date(2003,10,14).ctime()
print("\n day and month:",t,d)
# Out:
#  day and month: 2003-10-14 Tue Oct 14 00:00:00 2003

# %%
today=date.today()
print("\ntoday:",today)
print("\nCurrent year:",today.year)
print("\nCurrent month:",today.month)
print("\nCurrent day:",today.day)
# Out:
# today: 2024-05-07
#
# Current year: 2024
#
# Current month: 5
#
# Current day: 7

# %%
import datetime
cd=datetime.datetime.now()
print(cd)
# Out:
# 2024-05-07 14:49:54.144511

# %%
res=cd.strftime("%y")
print("\ntwo-digit year:",res)
# Out:
# two-digit year: 24

# %%
res1=cd.strftime("%Y")
print("\nfour-digit year:",res1)
# Out:
# four-digit year: 2024

# %%
res=cd.strftime("%m")
print("\nTwo-digit month[01,12]:",res)
# Out:
# Two-digit month[01,12]: 05

# %%
res=cd.strftime("%b")
print("\nshort version of month:",res)
# Out:
# short version of month: May

# %%
res=cd.strftime("%B")
print("\nfull name of month:",res)
# Out:
# full name of month: May

# %%
res=cd.strftime("%j")
print("\nDays of the year:",res)
# Out:
# Days of the year: 128

# %%
res=cd.strftime("%D")
print("\nshortcut for %m/%d/%y(eg.,04/18/12):",res)
# Out:
# shortcut for %m/%d/%y(eg.,04/18/12): 05/07/24

# %%
res=cd.strftime("%d")
print("\ntwo-digit day[01,31]:",res)
# Out:
# two-digit day[01,31]: 07

# %%
res=cd.strftime("%a")
print("\nshort version of day:",res)
# Out:
# short version of day: Tue

# %%
res=cd.strftime("%A")
print("\nfull name of a day:",res)
# Out:
# full name of a day: Tuesday

# %%
res=cd.strftime("%H")
print("\nHour(24-hour clock)[00,23]:",res)
# Out:
# Hour(24-hour clock)[00,23]: 14

# %%
res=cd.strftime("%I")
print("\nHour(12-hour clock)[01,12]:",res)
# Out:
# Hour(12-hour clock)[01,12]: 02

# %%
res=cd.strftime("%M")
print("\nTwo-digit minute[00,59]:",res)
# Out:
# Two-digit minute[00,59]: 49

# %%
res=cd.strftime("%S")
print("\nsecond[00,61](seconds60,61 account for leap seconds):",res)
# Out:
# second[00,61](seconds60,61 account for leap seconds): 54

# %%
res=cd.strftime("%F")
print("\nShortcut for %Y-%m-%d(e.g.,2012-4-18):",res)
# Out:
# Shortcut for %Y-%m-%d(e.g.,2012-4-18): 2024-05-07

# %%
res=cd.strftime("%f")
print("\nmicrosecond as an integer, zero-padded (from 000000 to 999999):",res)
# Out:
# microsecond as an integer, zero-padded (from 000000 to 999999): 144511

# %%
res=cd.strftime("%p")
print("\nlocale equivalent of AM or PM:",res)
# Out:
# locale equivalent of AM or PM: PM

# %%
res=cd.strftime("%x")
print("\nlocale-appropriate formatted date(eg.,in the united states,may',2012 yields '05/01/2012'):",res)
# Out:
# locale-appropriate formatted date(eg.,in the united states,may',2012 yields '05/01/2012'): 05/07/24

# %%
res=cd.strftime("%X")
print("\nlocale-appropriate time(e.g.,'04:24:12PM'):",res)
# Out:
# locale-appropriate time(e.g.,'04:24:12PM'): 14:49:54

# %%
import pandas as pd
import numpy as np
from datetime import datetime

dates=[datetime(2011,1,2),
       datetime(2011,1,5),
       datetime(2011,1,7),
       datetime(2011,1,8),
       datetime(2011,1,10),
       datetime(2011,1,12)]
ts=pd.Series(np.random.randn(6),index=dates)
print("\nDate index:\n",ts)
print("\nDate index alone from the series:\n",ts.index)
stamp=ts.index[2]
print("\nsecond index:\n",stamp)
# Out:
# Date index:
#  2011-01-02    0.937295
# 2011-01-05    0.217515
# 2011-01-07    0.600266
# 2011-01-08   -1.162111
# 2011-01-10   -0.191629
# 2011-01-12    0.856285
# dtype: float64
#
# Date index alone from the series:
#  DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)
#
# second index:
#  2011-01-07 00:00:00

# %%
longer_ts=pd.Series(np.random.randn(1000),index=pd.date_range("2000-01-01",periods=1000))
print("\ndaterange upto 1000 days:\n",longer_ts["2001"])
# Out:
# daterange upto 1000 days:
#  2001-01-01    0.781599
# 2001-01-02   -0.968609
# 2001-01-03   -1.016125
# 2001-01-04    0.819074
# 2001-01-05   -0.041707
#                 ...
# 2001-12-27   -0.437201
# 2001-12-28    1.622764
# 2001-12-29    0.102200
# 2001-12-30    0.993174
# 2001-12-31   -2.189529
# Freq: D, Length: 365, dtype: float64

# %%
print("\ndaterange-2001 year:\n",longer_ts["2001"])
# Out:
# daterange-2001 year:
#  2001-01-01    0.781599
# 2001-01-02   -0.968609
# 2001-01-03   -1.016125
# 2001-01-04    0.819074
# 2001-01-05   -0.041707
#                 ...
# 2001-12-27   -0.437201
# 2001-12-28    1.622764
# 2001-12-29    0.102200
# 2001-12-30    0.993174
# 2001-12-31   -2.189529
# Freq: D, Length: 365, dtype: float64

# %%
print("\ndaterange-05 month 2001 year:\n",longer_ts["2001-05"])
# Out:
# daterange-05 month 2001 year:
#  2001-05-01   -0.221292
# 2001-05-02   -1.829129
# 2001-05-03   -2.607978
# 2001-05-04   -0.363029
# 2001-05-05    1.021014
# 2001-05-06    0.483652
# 2001-05-07    0.138053
# 2001-05-08   -0.411459
# 2001-05-09   -0.876117
# 2001-05-10   -2.838058
# 2001-05-11    0.655451
# 2001-05-12   -1.401137
# 2001-05-13   -0.428196
# 2001-05-14   -0.481920
# 2001-05-15    0.503932
# 2001-05-16   -1.814296
# 2001-05-17   -1.142343
# 2001-05-18   -1.472543
# 2001-05-19   -2.315944
# 2001-05-20    1.140766
# 2001-05-21   -0.333821
# 2001-05-22    0.001666
# 2001-05-23   -1.108933
# 2001-05-24   -0.275408
# 2001-05-25    0.208808
# 2001-05-26   -1.523947
# 2001-05-27   -0.621512
# 2001-05-28   -1.294291
# 2001-05-29    2.404176
# 2001-05-30   -0.449997
# 2001-05-31    0.898167
# Freq: D, dtype: float64

# %%
print("\ndaterange-first few dates in 2000 year:\n",longer_ts["2000"].head())
# Out:
# daterange-first few dates in 2000 year:
#  2000-01-01   -0.537398
# 2000-01-02   -1.247690
# 2000-01-03    0.308628
# 2000-01-04    0.533485
# 2000-01-05    0.560794
# Freq: D, dtype: float64

# %%
print("\ndate range-first 15 dates in 02 month - 2001 year:\n",longer_ts["2000-02"].head(15))
# Out:
# date range-first 15 dates in 02 month - 2001 year:
#  2000-02-01   -0.143199
# 2000-02-02    0.844582
# 2000-02-03    0.344398
# 2000-02-04   -0.674589
# 2000-02-05   -1.203240
# 2000-02-06    0.607142
# 2000-02-07    0.882031
# 2000-02-08   -0.414695
# 2000-02-09    0.680990
# 2000-02-10   -0.278536
# 2000-02-11    1.417681
# 2000-02-12    1.047523
# 2000-02-13    1.628131
# 2000-02-14   -0.512732
# 2000-02-15   -0.456859
# Freq: D, dtype: float64

# %%
print("\ndaterange-rom 26-9-2001:ln",longer_ts[datetime(2000,9,26):])
# Out:
# daterange-rom 26-9-2001:ln 2000-09-26   -0.786097
# 2000-09-27    0.438823
# 2000-09-28   -0.543544
# 2000-09-29   -0.506267
# 2000-09-30   -1.450216
#                 ...
# 2002-09-22    0.385478
# 2002-09-23    0.465396
# 2002-09-24    1.028887
# 2002-09-25   -1.186156
# 2002-09-26   -1.767792
# Freq: D, Length: 731, dtype: float64

# %%
print("\ndaterange-from 26-9-2001 to 25-9-2002:\n",longer_ts[datetime(2001,9,26):datetime(2002,9,25)])
# Out:
# daterange-from 26-9-2001 to 25-9-2002:
#  2001-09-26    1.295486
# 2001-09-27   -0.335363
# 2001-09-28   -0.567899
# 2001-09-29    1.345891
# 2001-09-30    1.740858
#                 ...
# 2002-09-21    0.443573
# 2002-09-22    0.385478
# 2002-09-23    0.465396
# 2002-09-24    1.028887
# 2002-09-25   -1.186156
# Freq: D, Length: 365, dtype: float64

# %%
import pandas as pd
import numpy as np
from datetime import datetime
ran=pd.date_range("2020-08-15","2020-09-01")
print("Data range:\n",ran)
# Out:
# Data range:
#  DatetimeIndex(['2020-08-15', '2020-08-16', '2020-08-17', '2020-08-18',
#                '2020-08-19', '2020-08-20', '2020-08-21', '2020-08-22',
#                '2020-08-23', '2020-08-24', '2020-08-25', '2020-08-26',
#                '2020-08-27', '2020-08-28', '2020-08-29', '2020-08-30',
#                '2020-08-31', '2020-09-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
ran=pd.date_range("2020-07-15",periods=10)
print("\nDate range with periods and default day frequency:\n",ran)
# Out:
# Date range with periods and default day frequency:
#  DatetimeIndex(['2020-07-15', '2020-07-16', '2020-07-17', '2020-07-18',
#                '2020-07-19', '2020-07-20', '2020-07-21', '2020-07-22',
#                '2020-07-23', '2020-07-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
ran=pd.period_range("2020-07-15",periods=10,freq='H')
print("Daterange with periods and month frequency:\n",ran)
# Out:
# Daterange with periods and month frequency:
#  PeriodIndex(['2020-07-15 00:00', '2020-07-15 01:00', '2020-07-15 02:00',
#              '2020-07-15 03:00', '2020-07-15 04:00', '2020-07-15 05:00',
#              '2020-07-15 06:00', '2020-07-15 07:00', '2020-07-15 08:00',
#              '2020-07-15 09:00'],
#             dtype='period[H]')

# %%
ran=pd.period_range("2020-10",periods=10,freq="M")
print("\nDate range with periods and month frequency:\n",ran)
# Out:
# Date range with periods and month frequency:
#  PeriodIndex(['2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03',
#              '2021-04', '2021-05', '2021-06', '2021-07'],
#             dtype='period[M]')

# %%
ran=pd.timedelta_range(0,periods=8,freq="H")
print("\nZero day with hour frequency periods:\n",ran)
# Out:
# Zero day with hour frequency periods:
#  TimedeltaIndex(['0 days 00:00:00', '0 days 01:00:00', '0 days 02:00:00',
#                 '0 days 03:00:00', '0 days 04:00:00', '0 days 05:00:00',
#                 '0 days 06:00:00', '0 days 07:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %%
import pandas as pd
import numpy as np
from datetime import datetime
dates=[datetime(2020,1,5),datetime(2020,1,10),datetime(2020,1,15),datetime(2020,1,15),datetime(2020,1,20),datetime(2020,1,25)]
ts=pd.Series(np.random.randn(6),index=dates)
print("\nWith this date object, create a series with datetime index:\n",ts)
# Out:
# With this date object, create a series with datetime index:
#  2020-01-05    1.629484
# 2020-01-10    1.305068
# 2020-01-15    0.161759
# 2020-01-15   -0.545523
# 2020-01-20    1.429319
# 2020-01-25    0.652041
# dtype: float64

# %%
res=ts.truncate(after="1/15/2020")
print("\nTruncate method to truncate datetime series:\n",res)
# Out:
# Truncate method to truncate datetime series:
#  2020-01-05    1.629484
# 2020-01-10    1.305068
# 2020-01-15    0.161759
# 2020-01-15   -0.545523
# dtype: float64

# %%
da=pd.date_range("10/1/2022",periods=10,freq="W-SUN")
print("\nDate range with day periods:\n",da)
# Out:
# Date range with day periods:
#  DatetimeIndex(['2022-10-02', '2022-10-09', '2022-10-16', '2022-10-23',
#                '2022-10-30', '2022-11-06', '2022-11-13', '2022-11-20',
#                '2022-11-27', '2022-12-04'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
long_df=pd.DataFrame(np.random.randn(10,4),index=da,columns=list("ABCD"))
print("\nMulti-column DataFrame with datetime index:\n",long_df)
# Out:
# Multi-column DataFrame with datetime index:
#                     A         B         C         D
# 2022-10-02  0.379969 -0.009116 -0.217414 -0.423230
# 2022-10-09 -0.543788 -0.131693  0.000620 -0.527146
# 2022-10-16 -0.399753  0.434236  0.231863 -0.578611
# 2022-10-23 -0.265377 -0.455400 -0.868500 -0.627234
# 2022-10-30 -0.373376 -0.461574 -0.839345  1.156931
# 2022-11-06 -0.547471 -1.051512  0.197393 -1.468406
# 2022-11-13  1.647220 -0.084020 -0.430029 -1.049439
# 2022-11-20  0.738853 -0.565306 -1.675376  1.925122
# 2022-11-27  0.064477 -1.886416 -0.132634  0.310939
# 2022-12-04  0.966973  0.073968  0.361611 -1.403670

# %%
date=pd.DatetimeIndex(["1/1/2020","1/2/2020","1/2/2020","1/2/2020","1/3/2020"])
ts1=pd.Series(np.arange(5),index=date)
print("\nDuplicate datetime index:\n",ts1)
# Out:
# Duplicate datetime index:
#  2020-01-01    0
# 2020-01-02    1
# 2020-01-02    2
# 2020-01-02    3
# 2020-01-03    4
# dtype: int64

# %%
group=ts1.groupby(level=0)
print("\nRepeated date counts:\n",group.count())
# Out:
# Repeated date counts:
#  2020-01-01    1
# 2020-01-02    3
# 2020-01-03    1
# dtype: int64
